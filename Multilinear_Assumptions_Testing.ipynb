# %%
import pandas as pd 
import numpy as np
import matplotlib as plt 
import seaborn as sns

# %%
data = pd.read_csv('50_Startups.csv')
data.head(50)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.shape #This is used to find out the number of rows and columns (rows, columns)
# Out:
# (50, 5)

# %%
data.isnull().values.any() # Used to find whether there is missing value in the data or not
# Out:
# False

# %%
conda install -c conda-forge statsmodels
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :3].values
print(X)
Y = dataset.iloc[:, -1].values
print(Y)
dataset.head(50)
# Out:
# [[165349.2  136897.8  471784.1 ]
#  [162597.7  151377.59 443898.53]
#  [153441.51 101145.55 407934.54]
#  [144372.41 118671.85 383199.62]
#  [142107.34  91391.77 366168.42]
#  [131876.9   99814.71 362861.36]
#  [134615.46 147198.87 127716.82]
#  [130298.13 145530.06 323876.68]
#  [120542.52 148718.95 311613.29]
#  [123334.88 108679.17 304981.62]
#  [101913.08 110594.11 229160.95]
#  [100671.96  91790.61 249744.55]
#  [ 93863.75 127320.38 249839.44]
#  [ 91992.39 135495.07 252664.93]
#  [119943.24 156547.42 256512.92]
#  [114523.61 122616.84 261776.23]
#  [ 78013.11 121597.55 264346.06]
#  [ 94657.16 145077.58 282574.31]
#  [ 91749.16 114175.79 294919.57]
#  [ 86419.7  153514.11      0.  ]
#  [ 76253.86 113867.3  298664.47]
#  [ 78389.47 153773.43 299737.29]
#  [ 73994.56 122782.75 303319.26]
#  [ 67532.53 105751.03 304768.73]
#  [ 77044.01  99281.34 140574.81]
#  [ 64664.71 139553.16 137962.62]
#  [ 75328.87 144135.98 134050.07]
#  [ 72107.6  127864.55 353183.81]
# ...

# %%
conda install -c conda-forge statsmodels
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS (Y, X)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Fri, 27 May 2022   Prob (F-statistic):           4.53e-30
# Time:                        23:32:29   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 3, figsize = (12, 6))
ax[0].scatter(x = dataset['R&D Spend'], y = dataset['Profit'])
ax[0].set_title('Profit vs. R&D Spend ')
ax[1].scatter(x = dataset['Administration'], y = dataset['Profit'])
ax[1].set_title('Profit vs. Administration ')
ax[2].scatter(x = dataset['Marketing Spend'], y = dataset['Profit'])
ax[2].set_title('Profit vs. Marketing Spend')
fig.tight_layout(pad=3.0)
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(dataset, height = 2);

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)

# %%
Y_pred = Y_pred.reshape(len(Y_pred),1)
Y_test = Y_test.reshape(len(Y_test),1)
residual = Y_test - Y_pred

# %%
plt.scatter(residual, Y_pred)
plt.title('Residual value vs Predicted Value')
plt.ylabel('Residual Value')
plt.xlabel('Predicted Value')
plt.show()

# %%
# !pip install statsmodels --quiet

# %%
import statsmodels.api as sm
model_fit = sm.OLS(Y_train, X_train).fit()
residual = model_fit.resid
figure = sm.qqplot(residual, fit = True, line = '45')
plt.show()

# %%
model_fit = sm.OLS(Y_train, X_train).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     258.7
# Date:                Fri, 27 May 2022   Prob (F-statistic):           2.09e-24
# Time:                        23:37:36   Log-Likelihood:                -418.87
# No. Observations:                  40   AIC:                             845.7
# Df Residuals:                      36   BIC:                             852.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.774e+04   6934.042      6.885      0.000    3.37e+04    6.18e+04
# ...
